# %%
# !pip install httpx -q

# %%
3. Запустите все ячейки последовательно4. В последней ячейке запустите main() для тестированияТребования:- Установите API ключ Perplexity в переменную окружения PERPLEXITY_API_KEY- Или введите ключ при запуске main()"""# Запустите эту ячейку для проверки работы нейро-сотрудника# await main()

# %%
await main()
